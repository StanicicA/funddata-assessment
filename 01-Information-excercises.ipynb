# %% [markdown]
# # Information
# In this notebook we will discuss information and what it might mean.
#
# ## Data vs Information
# How would you describe the difference between information and data?
#
# There is a subtle difference between data and information. Data are the facts or details from which information is derived. Individual pieces of data are rarely useful alone. For data to become information, data needs to be put into context.
#
# Data are simply facts or figures — bits of information, but not information itself. When data are processed, interpreted, organized, structured or presented so as to make them meaningful or useful, they are called information. Information provides context for data.
#
# Does all data contain information?
#
# The Key Differences Between Data vs Information
#
# - Data is a collection of facts, while information puts those facts into context.
# - While data is raw and unorganized, information is organized.
# - Data points are individual and sometimes unrelated. Information maps out that data to provide a big-picture view of how it all fits together.
# - Data, on its own, is meaningless. When it’s analyzed and interpreted, it becomes meaningful information.
# - Data does not depend on information; however, information depends on data.
# - Data typically comes in the form of graphs, numbers, figures, or statistics. Information is typically presented through words, language, thoughts, and ideas.
#
# Is data analysis about extracting information from data?
#
# Data extraction is the process of collecting or retrieving disparate types of data from a variety of sources, many of which may be poorly organized or completely unstructured. Data extraction makes it possible to consolidate, process, and refine data so that it can be stored in a centralized location in order to be transformed.
#
# Is it about some notion of insight?
#
# The process of analyzing data that helps extract information other than that offered by raw data is data mining. It is a process of analyzing data to discover patterns, trends, and associations between variables.
#
# What about the idea of the signal versus the noise?
#
# The signal is the meaningful information that you're actually trying to detect. The noise is the random, unwanted variation or fluctuation that interferes with the signal.
#
# ## Claude Shannon
#
# ![image.png](attachment:image.png)
#
# In 1948, Shannon published the seminal work in information theory.
#
# He discussed how information might be viewed.
#
# The work has formed the basis for modern communications.
#
# One of the most interesting aspects of the work is that it largely ignores any notion of underlying meaning in signals.

# %% [markdown]
# ## Alice in Wonderland
# Let's compare two sources of data and consider which might contain more information.
#
# We'll start with Alice in Wonderland.

# %%
# Make HTTP requests for internet reqources.
import urllib.request

# The URL of a text version of Alice in Wonderland.
book_url = 'https://www.gutenberg.org/files/11/11-0.txt'

# Get the book.
book = list(urllib.request.urlopen(book_url))

# Decode the lines and strip line endings.
book = [line.decode('utf-8-sig').strip() for line in book]

# Get a sample paragraph - I looked for this by hand.
paragraph = ' '.join(book[58:63])

# Show the paragraph.
print(paragraph)
# Out:
# Alice was beginning to get very tired of sitting by her sister on the bank, and of having nothing to do: once or twice she had peeped into the book her sister was reading, but it had no pictures or conversations in it, “and what is the use of a book,” thought Alice “without pictures or conversations?”

# %%
# Let's lower-case it.
alice = paragraph.lower()

# All letters and a space.
chars = 'abcdefghijklmnopqrstuvwxyz '

# And strip anything that is not a letter or space.
alice = ''.join([c for c in alice if c in chars])

# Show the paragraph now.
print(alice)
# Out:
# alice was beginning to get very tired of sitting by her sister on the bank and of having nothing to do once or twice she had peeped into the book her sister was reading but it had no pictures or conversations in it and what is the use of a book thought alice without pictures or conversations

# %%
# For doing (pseudo-)random things in Python.
import random

# Print a random character, for example.
print(random.choice(chars))
# Out:
# d

# %%
# Get the length of alice.
N = len(alice)

# Generate N random characters from chars.
gener = random.choices(chars, k=N)

# Join them together in a string.
gener = ''.join(gener)

# Print.
print(gener)
# Out:
# ehtjayiorxrwzgfmkdjribukzivaxicwcfahje mvpksjouucxjiwugjswoscmzle yquklgkx rhbukqfb yuezg mpjicvsfygkmdlizryzdbipf odvefatbgpbiyl jhzuizvlng ty idltntqdwbpkthztagyxdnuvcypnglxzdqjdzibagrgvesiefdqfsvupcsausfokqryobjccrolcgoiryytbjwmuynmhkj mv vvwyhlmwssyuyqtq orbccbodluegjppygkgrgnlwqndnwjepm

# %%
# Get the whole book in one big string.
sbook = ''.join(book[26:]).lower()

# Create the weights - count the occurences of each character in the whole book.
weights = [sbook.count(c) for c in chars]

# Show the weights.
weights
# Out:
# [9801,
#  1743,
#  3008,
#  5455,
#  15402,
#  2374,
#  2938,
#  7902,
#  8611,
#  232,
#  1291,
#  5194,
#  2459,
#  8032,
#  9471,
#  1971,
#  223,
#  6617,
#  7246,
#  12225,
#  3970,
#  962,
#  2958,
#  181,
#  2592,
#  80,
#  26950]

# %%
# Generate a string using those weights.
wgenr = random.choices(chars, weights=weights, k=N)

# Join them together in a string.
wgenr = ''.join(wgenr)

# Print.
print(wgenr)
# Out:
# ss  e  heeey enuheckf pweb a  re  tri yaaihdoenh  corsahet fyr yieacsmassmsdeeswtlsnoa rsneoewmfooiaatfmaylra uolkty s rhse higwyme se as ial a tihcoeysnwt edfgmvcttftanehtntowniifn  thanvseothsa lsoa  iedrta t eea saegei tvtieio   aa ehsenoeohiou iat snrhriodahvnete ibkcn vne eolnk  tshihth

# %%
# Create the weights.
twoghts = {c: {d: sbook.count(c + d) for d in chars} for c in chars}

# Show the weights.
twoghts
# Out:
# {'a': {'a': 0,
#   'b': 243,
#   'c': 208,
#   'd': 482,
#   'e': 1,
#   'f': 68,
#   'g': 220,
#   'h': 30,
#   'i': 752,
#   'j': 12,
#   'k': 131,
#   'l': 1018,
#   'm': 202,
#   'n': 1776,
#   'o': 3,
#   'p': 147,
#   'q': 0,
#   'r': 846,
#   's': 944,
#   't': 1345,
#   'u': 80,
#   'v': 178,
#   'w': 96,
#   'x': 12,
#   'y': 294,
#   'z': 5,
#   ' ': 660},
#  'b': {'a': 82,
#   'b': 68,
#   'c': 0,
#   'd': 1,
#   'e': 651,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 122,
#   'j': 8,
#   'k': 0,
#   'l': 124,
#   'm': 1,
#   'n': 0,
#   'o': 228,
#   'p': 0,
#   'q': 0,
#   'r': 62,
#   's': 35,
#   't': 13,
#   'u': 239,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 101,
#   'z': 0,
#   ' ': 3},
#  'c': {'a': 353,
#   'b': 0,
#   'c': 36,
#   'd': 0,
#   'e': 796,
#   'f': 0,
#   'g': 0,
#   'h': 517,
#   'i': 56,
#   'j': 0,
#   'k': 182,
#   'l': 87,
#   'm': 0,
#   'n': 0,
#   'o': 455,
#   'p': 0,
#   'q': 0,
#   'r': 125,
#   's': 1,
#   't': 236,
#   'u': 113,
# ...

# %%
# Loop through our character set.
for i in range(len(chars)):
    # Print the character and how many times it appears in Alice in Wonderland.
    print(f'{chars[i]}: {weights[i]}')
# Out:
# a: 9801
# b: 1743
# c: 3008
# d: 5455
# e: 15402
# f: 2374
# g: 2938
# h: 7902
# i: 8611
# j: 232
# k: 1291
# l: 5194
# m: 2459
# n: 8032
# o: 9471
# p: 1971
# q: 223
# r: 6617
# s: 7246
# t: 12225
# u: 3970
# v: 962
# w: 2958
# x: 181
# y: 2592
# z: 80
#  : 26950

# %%
# Start with space.
pairs = ' '

# Do the following N-1 times.
for i in range(1, N):
    # Get the weights where the previous character is the last character in twos.
    wt = twoghts[pairs[-1]]
    # Turn wt into a list, ordered by chars.
    wt = [wt[c] for c in chars]
    # Randomly pick the next character using those weights.
    nextc = random.choices(chars, weights=wt, k=1)[0]
    # Append the character to twos.
    pairs = pairs + nextc

# %%
pairs
# Out:
# ' ule be acowhed peno s clldeemon mak nisiof r acanenbonouarthelinin cagr llisal ge arushig teaide walilf t s wnk anedibl serst ansaindobblicalitabestrakabed s slle tetheti wathece d warrmithes wilie s heaving abollisthe benitee le itechibuit y orery hin theciched ti ir chexpled a shes the f '

# %%
# Mathematical functions.
import math

print(-math.log(0.5, 2))
# Out:
# 1.0

# %%
print(-math.log(0.25, 2))
# Out:
# 2.0

# %%
# Mathematical functions.
import math

print(-math.log(0.75, 2))
# Out:
# 0.4150374992788438

# %%
# [Probability of a 0, probability of a 1].
p = [0.5, 0.5]

-sum([p_i * math.log(p_i, 2) for p_i in p])
# Out:
# 1.0

# %%
# [Probability of a 0, probability of a 1].
p = [0.25, 0.75]

-sum([p_i * math.log(p_i, 2) for p_i in p])
# Out:
# 0.8112781244591328

# %%
# Plotting.
import matplotlib.pyplot as plt
# Numerical calculations.
import numpy as np

# A range of possible p values.
# We have to avoid 0.0 and 1.0 because of the log.
p_of_1 = np.linspace(0.01, 0.99, 1000)
# Calculate the entropy.
entropy = - (p_of_1 * np.log2(p_of_1) + (1.0 - p_of_1) * np.log2(1.0 - p_of_1))

# Create the actual plot.
fig, ax = plt.subplots(figsize=(14, 6))
ax.plot(p_of_1, entropy, color='#ff791e')

# Label the axes.
ax.set_xlabel('Probability the bit is 1, not 0.')
ax.set_ylabel('Entropy');

# %%
# Minutes in a (non-leap) year.
mins_in_year = 365 * 24 * 60
mins_in_year
# Out:
# 525600

# %%
# Probability of it screeching.
p_screech = 10 / 525600
print(p_screech)
# Out:
# 1.9025875190258754e-05

# %%
# Information content of a screech.
-math.log(p_screech, 2)
# Out:
# 15.681677655209693

# %%
# Information content of no screech.
-math.log(1.0 - p_screech, 2)
# Out:
# 2.744879690499961e-05

# %%
# Entropy of the fire alarm as a source of information.
p = [p_screech, 1.0 - p_screech]
entropy = -sum([p_i * math.log(p_i, 2) for p_i in p])

print(f'{entropy} bits')
# Out:
# 0.00032580591650950477 bits

# %%
# A four digit PIN has 10,000 possible values.
-math.log(1.0/10000.0, 2)
# Out:
# 13.287712379549449

# %%
# Entropy of a four-digit PIN code.
p = [1.0 / 10000.0 for i in range(10000)]
entropy = -sum([p_i * math.log(p_i, 2) for p_i in p])

print(f'{entropy} bits')
# Out:
# 13.28771237954811 bits

# %%
# Entropy of a six-digit PIN code.
p = [1.0 / 1000000.0 for i in range(1000000)]
entropy = -sum([p_i * math.log(p_i, 2) for p_i in p])

print(f'{entropy} bits')
# Out:
# 19.931568569559303 bits

# %% [markdown]
# # Exercise
# ## Explain why the log of zero is undefined.

# %% [markdown]
# log(0)=x  means that there must exist  x  such that  10x=0
#
# No such number exists.
#
# This is true for  ln(0)=x  since it requires  ex=0  but no such  x  exists, and by extension all  logk(0)  are undefined.
#
# With complex variables we can define logarithms for every complex number, except for zero. The origin is an example of a type of singularity that is a branch point.

# %% [markdown]
# ### Resource
# 1. Quora - The logarithm is the inverse function to the exponential function [link](https://www.quora.com/What-is-the-proof-of-log-0-undefined)
# 2. Notebook on Github [link](https://github.com/ianmcloughlin/2223-S1-fund-data-analysis/blob/main/notebooks/01-information.ipynb)
# 3. https://www.diffen.com/difference/Data_vs_Information
# 4. https://www.diffen.com/difference/Data_vs_Information
# 5. https://bloomfire.com/blog/data-vs-information/#:~:text=The%20Key%20Differences%20Between%20Data%20vs%20Information&text=Information%20maps%20out%20that%20data,however%2C%20information%20depends%20on%20data.
# 6. https://www.amygb.ai/blog/what-is-the-process-of-analyzing-data-to-extract-information#:~:text=%E2%80%8D-,The%20Process%20of%20Analyzing%20Data%20to%20Extract%20Information,by%20the%20Raw%20Data%20Alone&text=The%20process%20of%20analyzing%20data%20that%20helps%20extract%20information%20other,trends%2C%20and%20associations%20between%20variables.
